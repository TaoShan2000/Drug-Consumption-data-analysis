# %%
  import pandas as pd
import numpy as np

# %%
file_path = "/content/drug_consumption (3).data"

# %%
drug_data = pd.read_csv(file_path, delimiter=",")

# %%
print(drug_data)
# Out:
#          1  0.49788  0.48246  -0.05921  ...  CL0.10  CL2.2  CL0.11  CL0.12
# 0        2 -0.07854 -0.48246   1.98437  ...     CL0    CL4     CL0     CL0
# 1        3  0.49788 -0.48246  -0.05921  ...     CL1    CL0     CL0     CL0
# 2        4 -0.95197  0.48246   1.16365  ...     CL0    CL2     CL0     CL0
# 3        5  0.49788  0.48246   1.98437  ...     CL2    CL2     CL0     CL0
# 4        6  2.59171  0.48246  -1.22751  ...     CL0    CL6     CL0     CL0
# ...    ...      ...      ...       ...  ...     ...    ...     ...     ...
# 1879  1884 -0.95197  0.48246  -0.61113  ...     CL0    CL0     CL0     CL5
# 1880  1885 -0.95197 -0.48246  -0.61113  ...     CL4    CL5     CL0     CL0
# 1881  1886 -0.07854  0.48246   0.45468  ...     CL2    CL6     CL0     CL0
# 1882  1887 -0.95197  0.48246  -0.61113  ...     CL3    CL4     CL0     CL0
# 1883  1888 -0.95197 -0.48246  -0.61113  ...     CL3    CL6     CL0     CL2
#
# [1884 rows x 32 columns]

# %%
df = drug_data.drop(columns=['1'])
df
# Out:
#       0.49788  0.48246  -0.05921  0.96082  ...  CL0.10  CL2.2  CL0.11  CL0.12
# 0    -0.07854 -0.48246   1.98437  0.96082  ...     CL0    CL4     CL0     CL0
# 1     0.49788 -0.48246  -0.05921  0.96082  ...     CL1    CL0     CL0     CL0
# 2    -0.95197  0.48246   1.16365  0.96082  ...     CL0    CL2     CL0     CL0
# 3     0.49788  0.48246   1.98437  0.96082  ...     CL2    CL2     CL0     CL0
# 4     2.59171  0.48246  -1.22751  0.24923  ...     CL0    CL6     CL0     CL0
# ...       ...      ...       ...      ...  ...     ...    ...     ...     ...
# 1879 -0.95197  0.48246  -0.61113 -0.57009  ...     CL0    CL0     CL0     CL5
# 1880 -0.95197 -0.48246  -0.61113 -0.57009  ...     CL4    CL5     CL0     CL0
# 1881 -0.07854  0.48246   0.45468 -0.57009  ...     CL2    CL6     CL0     CL0
# 1882 -0.95197  0.48246  -0.61113 -0.57009  ...     CL3    CL4     CL0     CL0
# 1883 -0.95197 -0.48246  -0.61113  0.21128  ...     CL3    CL6     CL0     CL2
#
# [1884 rows x 31 columns]

# %%
df.columns = ['Age','Gender','Education','Country','Ethnicity','Nscore','Escore','Oscore','Ascore','Cscore','Impulsive','SS',
              'Alcohol','Amphet','Amyl','Benzos','Caff','Cannabis','Choc','Coke','Crack','Ecstasy','Heroin','Ketamine','Legalh',
              'LSD','Meth','Mushrooms','Nicotine','Semer','VSA']
df = df.replace({'CL0':'0','CL1':'1',
                     'CL2':'2','CL3':'3',
                     'CL4':'4','CL5':'5',
                     'CL6':'6'})
df
# Out:
#           Age   Gender  Education  Country  ...  Mushrooms  Nicotine  Semer  VSA
# 0    -0.07854 -0.48246    1.98437  0.96082  ...          0         4      0    0
# 1     0.49788 -0.48246   -0.05921  0.96082  ...          1         0      0    0
# 2    -0.95197  0.48246    1.16365  0.96082  ...          0         2      0    0
# 3     0.49788  0.48246    1.98437  0.96082  ...          2         2      0    0
# 4     2.59171  0.48246   -1.22751  0.24923  ...          0         6      0    0
# ...       ...      ...        ...      ...  ...        ...       ...    ...  ...
# 1879 -0.95197  0.48246   -0.61113 -0.57009  ...          0         0      0    5
# 1880 -0.95197 -0.48246   -0.61113 -0.57009  ...          4         5      0    0
# 1881 -0.07854  0.48246    0.45468 -0.57009  ...          2         6      0    0
# 1882 -0.95197  0.48246   -0.61113 -0.57009  ...          3         4      0    0
# 1883 -0.95197 -0.48246   -0.61113  0.21128  ...          3         6      0    2
#
# ...

# %%
df.to_csv('dfnew.csv',index = False)

# %%
df.to_csv('df.csv',index = False)

# %%
df['Age'] = df.Age.astype(str)
df['Age']
# Out:
# 0                  -0.07854
# 1       0.49788000000000004
# 2       -0.9519700000000001
# 3       0.49788000000000004
# 4                   2.59171
#                ...
# 1879    -0.9519700000000001
# 1880    -0.9519700000000001
# 1881               -0.07854
# 1882    -0.9519700000000001
# 1883    -0.9519700000000001
# Name: Age, Length: 1884, dtype: object

# %%
df['Age'] = df['Age'].replace(['-0.07854'], '25-34')
df['Age'] = df['Age'].replace(['-0.9519700000000001'], '18-24')
df['Age'] = df['Age'].replace(['0.49788000000000004'], '35-44')
df['Age'] = df['Age'].replace(['2.59171'], '65+')
df['Age'] = df['Age'].replace(['1.09449'], '45-54')
df['Age'] = df['Age'].replace(['1.82213'], '55-64')
df
# Out:
#         Age   Gender  Education  Country  ...  Mushrooms  Nicotine  Semer  VSA
# 0     25-34 -0.48246    1.98437  0.96082  ...          0         4      0    0
# 1     35-44 -0.48246   -0.05921  0.96082  ...          1         0      0    0
# 2     18-24  0.48246    1.16365  0.96082  ...          0         2      0    0
# 3     35-44  0.48246    1.98437  0.96082  ...          2         2      0    0
# 4       65+  0.48246   -1.22751  0.24923  ...          0         6      0    0
# ...     ...      ...        ...      ...  ...        ...       ...    ...  ...
# 1879  18-24  0.48246   -0.61113 -0.57009  ...          0         0      0    5
# 1880  18-24 -0.48246   -0.61113 -0.57009  ...          4         5      0    0
# 1881  25-34  0.48246    0.45468 -0.57009  ...          2         6      0    0
# 1882  18-24  0.48246   -0.61113 -0.57009  ...          3         4      0    0
# 1883  18-24 -0.48246   -0.61113  0.21128  ...          3         6      0    2
#
# ...

# %%
df.dtypes
# Out:
# Age           object
# Gender       float64
# Education    float64
# Country      float64
# Ethnicity    float64
# Nscore       float64
# Escore       float64
# Oscore       float64
# Ascore       float64
# Cscore       float64
# Impulsive    float64
# SS           float64
# Alcohol       object
# Amphet        object
# Amyl          object
# Benzos        object
# Caff          object
# Cannabis      object
# Choc          object
# Coke          object
# Crack         object
# Ecstasy       object
# Heroin        object
# Ketamine      object
# Legalh        object
# LSD           object
# Meth          object
# Mushrooms     object
# Nicotine      object
# Semer         object
# VSA           object
# dtype: object

# %%
df['Gender'] = df.Gender.astype(str)
df['Gender'] = df['Gender'].replace(['-0.48246000000000006'], 'Male')
df['Gender'] = df['Gender'].replace(['0.48246000000000006'], 'Female')
df
# Out:
#         Age  Gender  Education  Country  ...  Mushrooms  Nicotine  Semer  VSA
# 0     25-34    Male    1.98437  0.96082  ...          0         4      0    0
# 1     35-44    Male   -0.05921  0.96082  ...          1         0      0    0
# 2     18-24  Female    1.16365  0.96082  ...          0         2      0    0
# 3     35-44  Female    1.98437  0.96082  ...          2         2      0    0
# 4       65+  Female   -1.22751  0.24923  ...          0         6      0    0
# ...     ...     ...        ...      ...  ...        ...       ...    ...  ...
# 1879  18-24  Female   -0.61113 -0.57009  ...          0         0      0    5
# 1880  18-24    Male   -0.61113 -0.57009  ...          4         5      0    0
# 1881  25-34  Female    0.45468 -0.57009  ...          2         6      0    0
# 1882  18-24  Female   -0.61113 -0.57009  ...          3         4      0    0
# 1883  18-24    Male   -0.61113  0.21128  ...          3         6      0    2
#
# [1884 rows x 31 columns]

# %%
df['Education'] = df.Education.astype(str)
drug = df.replace({'Education': {'1.98437': 'Doctorate', '-0.059210000000000006': 'Professional certificate', 
                          '1.16365': 'Masters degree','-1.22751': 'Left school at 18 years',
                          '-0.6111300000000001': 'Some college or university',
                          '0.45468000000000003': 'University degree',
                          '-1.7379': 'Left school at 16 years',
                          '-1.43719': 'Left school at 17 years',
                          '-0.059210000000000006': 'Professional certificate',
                          '-2.43591': 'Left school before 16 years'}})
drug
# Out:
#         Age  Gender                   Education  ...  Nicotine  Semer  VSA
# 0     25-34    Male                   Doctorate  ...         4      0    0
# 1     35-44    Male    Professional certificate  ...         0      0    0
# 2     18-24  Female              Masters degree  ...         2      0    0
# 3     35-44  Female                   Doctorate  ...         2      0    0
# 4       65+  Female     Left school at 18 years  ...         6      0    0
# ...     ...     ...                         ...  ...       ...    ...  ...
# 1879  18-24  Female  Some college or university  ...         0      0    5
# 1880  18-24    Male  Some college or university  ...         5      0    0
# 1881  25-34  Female           University degree  ...         6      0    0
# 1882  18-24  Female  Some college or university  ...         4      0    0
# 1883  18-24    Male  Some college or university  ...         6      0    2
#
# [1884 rows x 31 columns]

# %%
drug = drug.astype(str)
drug.dtypes
# Out:
# Age          object
# Gender       object
# Education    object
# Country      object
# Ethnicity    object
# Nscore       object
# Escore       object
# Oscore       object
# Ascore       object
# Cscore       object
# Impulsive    object
# SS           object
# Alcohol      object
# Amphet       object
# Amyl         object
# Benzos       object
# Caff         object
# Cannabis     object
# Choc         object
# Coke         object
# Crack        object
# Ecstasy      object
# Heroin       object
# Ketamine     object
# Legalh       object
# LSD          object
# Meth         object
# Mushrooms    object
# Nicotine     object
# Semer        object
# VSA          object
# dtype: object

# %%
drug = drug.replace({'-0.09765':'Australia', '0.9608200000000001':'UK','0.24923':'Canada',
                     '-0.57009':'USA','0.21128000000000002':'Republic of Ireland',
                     '-0.28519':'Other','-0.46841000000000005':'New Zealand'})
drug
# Out:
#         Age  Gender                   Education  ... Nicotine Semer VSA
# 0     25-34    Male                   Doctorate  ...        4     0   0
# 1     35-44    Male    Professional certificate  ...        0     0   0
# 2     18-24  Female              Masters degree  ...        2     0   0
# 3     35-44  Female                   Doctorate  ...        2     0   0
# 4       65+  Female     Left school at 18 years  ...        6     0   0
# ...     ...     ...                         ...  ...      ...   ...  ..
# 1879  18-24  Female  Some college or university  ...        0     0   5
# 1880  18-24    Male  Some college or university  ...        5     0   0
# 1881  25-34  Female           University degree  ...        6     0   0
# 1882  18-24  Female  Some college or university  ...        4     0   0
# 1883  18-24    Male  Some college or university  ...        6     0   2
#
# [1884 rows x 31 columns]

# %%
drug.to_csv('drug.csv',index = False)

# %%
drug = drug.replace({'-0.31685':'White','0.126':'Mixed-White/Asian',
                     '-1.1070200000000001':'Black','-0.50212':'Asian',
                     '1.90725':'Mixed-Black/Asian','-0.22166':'Mixed-White/Black',
                     '0.1144':'Other'})
drug
# Out:
#         Age  Gender                   Education  ... Nicotine Semer VSA
# 0     25-34    Male                   Doctorate  ...        4     0   0
# 1     35-44    Male    Professional certificate  ...        0     0   0
# 2     18-24  Female              Masters degree  ...        2     0   0
# 3     35-44  Female                   Doctorate  ...        2     0   0
# 4       65+  Female     Left school at 18 years  ...        6     0   0
# ...     ...     ...                         ...  ...      ...   ...  ..
# 1879  18-24  Female  Some college or university  ...        0     0   5
# 1880  18-24    Male  Some college or university  ...        5     0   0
# 1881  25-34  Female           University degree  ...        6     0   0
# 1882  18-24  Female  Some college or university  ...        4     0   0
# 1883  18-24    Male  Some college or university  ...        6     0   2
#
# [1884 rows x 31 columns]

# %%
drug = drug.replace({'CL0':'0','CL1':'1',
                     'CL2':'2','CL3':'3',
                     'CL4':'4','CL5':'5',
                     'CL6':'6'})
drug
# Out:
#         Age  Gender                   Education  ... Nicotine Semer VSA
# 0     25-34    Male                   Doctorate  ...        4     0   0
# 1     35-44    Male    Professional certificate  ...        0     0   0
# 2     18-24  Female              Masters degree  ...        2     0   0
# 3     35-44  Female                   Doctorate  ...        2     0   0
# 4       65+  Female     Left school at 18 years  ...        6     0   0
# ...     ...     ...                         ...  ...      ...   ...  ..
# 1879  18-24  Female  Some college or university  ...        0     0   5
# 1880  18-24    Male  Some college or university  ...        5     0   0
# 1881  25-34  Female           University degree  ...        6     0   0
# 1882  18-24  Female  Some college or university  ...        4     0   0
# 1883  18-24    Male  Some college or university  ...        6     0   2
#
# [1884 rows x 31 columns]

# %%
drug.to_csv('drug.csv',index = False)
